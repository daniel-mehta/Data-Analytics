# %% [markdown]
# # Daniel Mehta

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#Imports the HTML into python
url = 'https://www.nfl.com/standings/league/2019/reg/'
response = requests.get(url)
html_content = response.text

# %%
#Subsets the HTML to only get the HTML of our table needed
soup = BeautifulSoup(html_content, 'html.parser')
table = soup.find('table', class_='d3-o-table')

# %%
#Gets all the column headers of our table
headers = []

for th in table.find('thead').find_all('th'):
    header_text = th.text.strip()
    headers.append(header_text)

print(headers)
# Out:
# ['NFL Team', 'W', 'L', 'T', 'PCT', 'PF', 'PA', 'Net Pts', 'Home', 'Road', 'Div', 'Pct', 'Conf', 'Pct', 'Non-Conf', 'Strk', 'Last 5']

# %%
#Creates a dataframe using the column headers from our table
df = pd.DataFrame(columns=headers)

df.head()
# Out:
# Empty DataFrame
# Columns: [NFL Team, W, L, T, PCT, PF, PA, Net Pts, Home, Road, Div, Pct, Conf, Pct, Non-Conf, Strk, Last 5]
# Index: []

# %%
#gets all our data within the table and adds it to our dataframe
rows = table.find('tbody').find_all('tr')

for row in rows:
    cells = row.find_all('td')
    row_data = [cell.get_text(strip=True) for cell in cells]

    df.loc[len(df)] = row_data

# %%
df.head(10)
# Out:
#                         NFL Team  W   L  T    PCT   PF   PA Net Pts  \
# 0      Cincinnati BengalsBengals  2  14  0  0.125  279  420    -141
# 1             Detroit LionsLions  3  12  1  0.219  341  423     -82
# 2  Washington CommandersRedskins  3  13  0  0.188  266  435    -169
# 3          New York GiantsGiants  4  12  0  0.250  341  451    -110
# 4     Arizona CardinalsCardinals  5  10  1  0.344  361  442     -81
# 5      Carolina PanthersPanthers  5  11  0  0.313  340  470    -130
# 6   Los Angeles ChargersChargers  5  11  0  0.313  337  345      -8
# 7         Miami DolphinsDolphins  5  11  0  0.313  306  494    -188
# 8         Cleveland BrownsBrowns  6  10  0  0.375  335  393     -58
# 9    Jacksonville JaguarsJaguars  6  10  0  0.375  300  397     -97
#
#         Home       Road        Div    Pct        Conf    Pct   Non-Conf Strk  \
# 0  2 - 6 - 0  0 - 8 - 0  1 - 5 - 0  0.167  2 - 10 - 0  0.167  0 - 4 - 0   1W
# 1  2 - 6 - 0  1 - 6 - 1  0 - 6 - 0  0.000   2 - 9 - 1  0.208  1 - 3 - 0   9L
# 2  1 - 7 - 0  2 - 6 - 0  0 - 6 - 0  0.000  2 - 10 - 0  0.167  1 - 3 - 0   4L
# 3  2 - 6 - 0  2 - 6 - 0  2 - 4 - 0  0.333   3 - 9 - 0  0.250  1 - 3 - 0   1L
# 4  2 - 5 - 1  3 - 5 - 0  1 - 5 - 0  0.167   3 - 8 - 1  0.292  2 - 2 - 0   1L
# 5  2 - 6 - 0  3 - 5 - 0  1 - 5 - 0  0.167  2 - 10 - 0  0.167  3 - 1 - 0   8L
# 6  2 - 6 - 0  3 - 5 - 0  0 - 6 - 0  0.000   3 - 9 - 0  0.250  2 - 2 - 0   3L
# 7  3 - 5 - 0  2 - 6 - 0  2 - 4 - 0  0.333   4 - 8 - 0  0.333  1 - 3 - 0   2W
# 8  4 - 4 - 0  2 - 6 - 0  3 - 3 - 0  0.500   6 - 6 - 0  0.500  0 - 4 - 0   3L
# 9  3 - 5 - 0  3 - 5 - 0  2 - 4 - 0  0.333   6 - 6 - 0  0.500  0 - 4 - 0   1W
#
#       Last 5
# 0  2 - 3 - 0
# 1  0 - 5 - 0
# 2  1 - 4 - 0
# 3  2 - 3 - 0
# 4  2 - 3 - 0
# 5  0 - 5 - 0
# 6  1 - 4 - 0
# 7  3 - 2 - 0
# 8  1 - 4 - 0
# 9  2 - 3 - 0
